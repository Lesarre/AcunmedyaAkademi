# %%
# !pip install opencv-python

# %%
img_path = "images/1.jpg"

# %%
import cv2

# %%
img = cv2.imread(img_path)

# %%
img.shape
# Out:
# (4608, 2592, 3)

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(data="data.yaml",epochs=1,imgsz=640,batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.138 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.130  Python-3.11.7 torch-2.7.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# ...

# %% [markdown]
# prediction

# %%
img_predict = cv2.imread("arac.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
model2 = YOLO("runs/detect/train/weights/best.pt")

# %%
results = model.predict(source=img_predict,conf=0.5)
# Out:
# 0: 480x640 1 plaka, 87.6ms
# Speed: 4.6ms preprocess, 87.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
boxes = results[0].boxes
annotated_img = img_predict.copy()

# %%
import matplotlib.pyplot as plt

# %%
for box in boxes:
    x1, y1, x2, y2 = map(int,box.xyxy[0])

    h, w, _ = annotated_img.shape

    cv2.rectangle(annotated_img,(x1,y1),(x2,y2),color=(255,0,0),thickness=2)

# %%
# %matplotlib inline
plt.imshow(annotated_img)
plt.show()

# %%
# !pip install pytesseract

# %%
import cv2

# %%
import pytesseract

# %%
img_path = "pexels-jessbaileydesign-762687.jpg"

# %%
img = cv2.imread(img_path)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
text = pytesseract.image_to_string(gray)

# %%
print("OCR ile tanınan metin:")
print(text)
